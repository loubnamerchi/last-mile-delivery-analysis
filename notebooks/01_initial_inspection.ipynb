# %% [markdown]
# ### imports and path setup

# %%
import sys
from pathlib import Path

# Add project root to path so we can import config and src
project_root = Path.cwd().parent
sys.path.append(str(project_root))

from config.config import RAW_DATA_FILE
from src.data.loader import load_raw_data, get_basic_info

# %% [markdown]
# ### load and confirm:

# %%
df = load_raw_data(RAW_DATA_FILE)
get_basic_info(df)
# Out:
# {'n_rows': 25000,
#  'n_columns': 15,
#  'columns': ['delivery_id',
#   'delivery_partner',
#   'package_type',
#   'vehicle_type',
#   'delivery_mode',
#   'region',
#   'weather_condition',
#   'distance_km',
#   'package_weight_kg',
#   'delivery_time_hours',
#   'expected_time_hours',
#   'delayed',
#   'delivery_status',
#   'delivery_rating',
#   'delivery_cost']}

# %% [markdown]
# ### first visual look:

# %%
df.head(10)
# Out:
#    delivery_id  delivery_partner      package_type vehicle_type delivery_mode  \
# 0       250.99         delhivery  automobile parts         bike      same day
# 1       250.99        xpressbees         cosmetics       ev van       express
# 2       250.99         shadowfax         groceries        truck       two day
# 3       250.99               dhl       electronics       ev van      same day
# 4       250.99               dhl          clothing          van       two day
# 5       250.99  amazon logistics         documents      ev bike       express
# 6       250.99         delhivery         groceries      scooter      same day
# 7       250.99        xpressbees     fragile items          van      same day
# 8       250.99         blue dart          clothing          van      same day
# 9       250.99         delhivery          pharmacy        truck      same day
#
#     region weather_condition  distance_km  package_weight_kg  \
# ...

# %% [markdown]
# ### dtypes as loaded by pandas:

# %%
df.dtypes
# Out:
# delivery_id            float64
# delivery_partner           str
# package_type               str
# vehicle_type               str
# delivery_mode              str
# region                     str
# weather_condition          str
# distance_km            float64
# package_weight_kg      float64
# delivery_time_hours        str
# expected_time_hours        str
# delayed                    str
# delivery_status            str
# delivery_rating          int64
# delivery_cost          float64
# dtype: object

# %% [markdown]
# ## Initial Inspection Notes
#
# - Dataset loads successfully with no errors.
# - Row/column count matches expectations (25,000 rows, 15 columns).
# - `delivery_id` looks like it should be a clean unique identifier — needs verification in Data Understanding (Step 5).
# - `delivery_time_hours` and `expected_time_hours` are loading as strings/timestamps instead of numeric hours — flagged for correction in Data Cleaning (Step 6).
# - No further judgments yet — full structural analysis happens in Step 5.
